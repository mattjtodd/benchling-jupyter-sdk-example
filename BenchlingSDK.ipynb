# %%
# !pip install benchling-sdk
# Out:
# ...
#   Using cached benchling_sdk-1.4.1-py3-none-any.whl (147 kB)
# ...
#   Using cached backoff-1.11.1-py2.py3-none-any.whl (13 kB)
# ...
#   Using cached benchling_api_client-2.0.3-py3-none-any.whl (3.9 MB)
# ...
#   Using cached attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# ...
#   Using cached dataclasses_json-0.5.7-py3-none-any.whl (25 kB)
# ...
#   Using cached httpx-0.22.0-py3-none-any.whl (84 kB)
# ...
#   Using cached PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
# ...
#   Using cached marshmallow-3.17.1-py3-none-any.whl (48 kB)
# ...
#   Using cached marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# ...
#   Using cached typing_inspect-0.8.0-py3-none-any.whl (8.7 kB)
# ...
#   Using cached httpcore-0.14.7-py3-none-any.whl (68 kB)
# ...
#   Using cached rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# ...
#   Using cached h11-0.12.0-py3-none-any.whl (54 kB)
# ...
#   Using cached mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# ...
#   Attempting uninstall: attrs
# ...

# %%
from benchling_sdk.benchling import Benchling
from benchling_sdk.auth.api_key_auth import ApiKeyAuth

benchling = Benchling(url="https://oribiotechtest.benchling.com/", auth_method=ApiKeyAuth("Benchling_Warehouse_Key"))

example_entities = benchling.dna_sequences.list()
for page in example_entities:
  for sequence in page:
    print(f"name: {sequence.name}\nid:{sequence.id}\n")
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       4 benchling = Benchling(url="https://oribiotechtest.benchling.com/", auth_method=ApiKeyAuth("Benchling_Warehouse_Key"))
#       6 example_entities = benchling.dna_sequences.list()
# ----> 7 for page in example_entities:
#       8   for sequence in page:
#       9     print(f"name: {sequence.name}\nid:{sequence.id}\n")
#
# File /opt/conda/lib/python3.10/site-packages/benchling_sdk/helpers/pagination_helpers.py:204, in PageIterator.__next__(self)
#     198 def __next__(self) -> List[Model]:
#     199     if (
#     200         self._next_token is None
#     201         or len(self._next_token) > 0
#     202         or (self._first_page is not None and self._iterations_count == 1 and self._forced_iteration)
#     203     ):
# --> 204         return self._fetch_data()
# ...
